# %% [markdown]
# # Explotación o uso del Modelo "DETECTOR DE PLACAS VEHICULARES"

# %%
# IMPORTAMOS LIBRERIAS
import glob 
from IPython.display import Image, display 
import yaml 
import os 
from datetime import date 
from datetime import datetime 

from PIL import Image  
import sys  
import cv2 
from matplotlib import pyplot as plt 
import numpy as np 
import openpyxl

import pandas as pd
import numpy as np

from google.colab import drive
from google.colab import files

# %% [markdown]
# # Importamos el directorio de las fotografias o video

# %%
# Anotamos las rutas del directorio de las fotografias y/o video

# !cp -av "/content/drive/MyDrive/deteccionConVideo.mp4" "/content/"  #copiamos el video
# !cp -av "/content/drive/MyDrive/deteccionConImagenes/" "/content/"  #copiamos el directorio de las fotografias
# !cp -av "/content/drive/MyDrive/modeloDetectorPlacas.pt" "/content/"  #copiamos el modelo
# Out:
# '/content/drive/MyDrive/deteccionConImagenes/' -> '/content/deteccionConImagenes'
# '/content/drive/MyDrive/deteccionConImagenes/IMG_20230110_172841.jpg' -> '/content/deteccionConImagenes/IMG_20230110_172841.jpg'
# '/content/drive/MyDrive/deteccionConImagenes/IMG_20230110_173744.jpg' -> '/content/deteccionConImagenes/IMG_20230110_173744.jpg'
# '/content/drive/MyDrive/deteccionConImagenes/IMG_20230110_173815.jpg' -> '/content/deteccionConImagenes/IMG_20230110_173815.jpg'
# '/content/drive/MyDrive/deteccionConImagenes/IMG_20230110_174347.jpg' -> '/content/deteccionConImagenes/IMG_20230110_174347.jpg'
# '/content/drive/MyDrive/deteccionConImagenes/IMG_20230110_174428.jpg' -> '/content/deteccionConImagenes/IMG_20230110_174428.jpg'
# '/content/drive/MyDrive/deteccionConImagenes/IMG_2023011O_174933.jpg' -> '/content/deteccionConImagenes/IMG_2023011O_174933.jpg'
# ...

# %% [markdown]
# # Importamos YOLOv5 e instalamos sus dependencias

# %%
# !git clone https://github.com/ultralytics/yolov5  # importamos YOLOv5
# %cd yolov5
# !pip install -qr requirements.txt # instalcion de dependencies (librerias)

import torch
#import os
from IPython.display import Image, clear_output 
from utils.downloads import attempt_download  

print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 2.0.0+cu118 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15101MB, multi_processor_count=40)

# %% [markdown]
# # DETECCIÓN CON IMAGENES

# %%
# DETECCIÓN CON IMAGENES
# !python detect.py --weights "/content/modeloDetectorPlacas.pt" --img 3008 --conf 0.1 --source  "/content/deteccionConImagenes" --save-txt  # añadir tamaño de imagen
# Out:
# detect: weights=['/content/modeloDetectorPlacas.pt'], source=/content/deteccionConImagenes, data=data/coco128.yaml, imgsz=[3008, 3008], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-133-gcca5e21 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5l summary: 267 layers, 46108278 parameters, 0 gradients, 107.6 GFLOPs
# image 1/62 /content/deteccionConImagenes/IMG_20230110_172841.jpg: 3008x3008 (no detections), 576.2ms
# image 2/62 /content/deteccionConImagenes/IMG_20230110_173744.jpg: 3008x3008 7 placas, 568.9ms
# image 3/62 /content/deteccionConImagenes/IMG_20230110_173815.jpg: 3008x3008 (no detections), 571.8ms
# ...

# %% [markdown]
# # DETECCIÓN CON VIDEO

# %%
# DETECCIÓN CON VIDEO
# !python detect.py --weights "/content/modeloDetectorPlacas.pt" --source "/content/deteccionConVideo.mp4" --save-txt

# %% [markdown]
# # Descargamos o Copiamos los resultados a DRIVE

# %%
# Copiamos los resultados al DRIVE

# !cp -av "/content/yolov5/runs/" "/content/drive/MyDrive/resultadosYolo/resultados_4abril/" #bien
